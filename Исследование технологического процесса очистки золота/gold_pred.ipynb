# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span><ul class="toc-item"><li><span><a href="#Постановка-задачи" data-toc-modified-id="Постановка-задачи-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Постановка задачи</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Расчет-эффективности" data-toc-modified-id="Расчет-эффективности-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Расчет эффективности</a></span></li><li><span><a href="#Используемая-метрика-качества" data-toc-modified-id="Используемая-метрика-качества-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Используемая метрика качества</a></span></li></ul></li><li><span><a href="#Импорт-библиотек" data-toc-modified-id="Импорт-библиотек-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Импорт библиотек</a></span></li><li><span><a href="#Загрузка-и-подготовка-данных" data-toc-modified-id="Загрузка-и-подготовка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Загрузка и подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Импорт-данных" data-toc-modified-id="Импорт-данных-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Импорт данных</a></span></li><li><span><a href="#Проверим,-что-эффективность-обогащения-рассчитана-правильно" data-toc-modified-id="Проверим,-что-эффективность-обогащения-рассчитана-правильно-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Проверим, что эффективность обогащения рассчитана правильно</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Предобработка данных</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Анализ-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки" data-toc-modified-id="Анализ-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Анализ концентрации металлов (Au, Ag, Pb) на различных этапах очистки</a></span></li><li><span><a href="#Анализ-размера-гранул-сырья" data-toc-modified-id="Анализ-размера-гранул-сырья-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Анализ размера гранул сырья</a></span></li><li><span><a href="#Анализ-суммарной-концентрации-всех-веществ-на-разных-стадиях" data-toc-modified-id="Анализ-суммарной-концентрации-всех-веществ-на-разных-стадиях-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Анализ суммарной концентрации всех веществ на разных стадиях</a></span></li></ul></li><li><span><a href="#Построение-модели" data-toc-modified-id="Построение-модели-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Построение модели</a></span><ul class="toc-item"><li><span><a href="#Разделение-на-выборки-и-масштабирование-данных" data-toc-modified-id="Разделение-на-выборки-и-масштабирование-данных-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Разделение на выборки и масштабирование данных</a></span></li><li><span><a href="#Функция-для-вычисления-sMAPE" data-toc-modified-id="Функция-для-вычисления-sMAPE-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Функция для вычисления sMAPE</a></span></li><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Обучение моделей</a></span><ul class="toc-item"><li><span><a href="#Оценка-среднего-целевого-признака-и-Dummy-модель" data-toc-modified-id="Оценка-среднего-целевого-признака-и-Dummy-модель-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>Оценка среднего целевого признака и Dummy модель</a></span></li><li><span><a href="#Rougher-Linear-Regression" data-toc-modified-id="Rougher-Linear-Regression-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>Rougher Linear Regression</a></span></li><li><span><a href="#Final.-Linear-Regression" data-toc-modified-id="Final.-Linear-Regression-5.3.3"><span class="toc-item-num">5.3.3&nbsp;&nbsp;</span>Final. Linear Regression</a></span></li><li><span><a href="#Rougher.-Случайный-лес" data-toc-modified-id="Rougher.-Случайный-лес-5.3.4"><span class="toc-item-num">5.3.4&nbsp;&nbsp;</span>Rougher. Случайный лес</a></span></li><li><span><a href="#Final-Случайный-лес" data-toc-modified-id="Final-Случайный-лес-5.3.5"><span class="toc-item-num">5.3.5&nbsp;&nbsp;</span>Final Случайный лес</a></span></li></ul></li><li><span><a href="#Выбор-лучшей-модели-и-проверка-на-тестовой-выборке" data-toc-modified-id="Выбор-лучшей-модели-и-проверка-на-тестовой-выборке-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Выбор лучшей модели и проверка на тестовой выборке</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# ### Постановка задачи
#
# Подготовим прототип модели машинного обучения для компании, разрабатывающей решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. В нашем распоряжении данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
# Основные шаги:
# * Подготовить данные;
# * Провести исследовательский анализ данных;
# * Построить и обучить модель.

# %% [markdown]
# ### Описание данных
#
# Данные находятся в трёх файлах:
# * gold_recovery_train_new.csv — обучающая выборка;
# * gold_recovery_test_new.csv — тестовая выборка;
# * gold_recovery_full_new.csv — исходные данные.
#
# Данные индексируются датой и временем получения информации (признак date). Соседние по времени параметры часто похожи.
# Некоторые параметры недоступны, потому что замеряются и/или рассчитываются значительно позже. Из-за этого в тестовой выборке отсутствуют некоторые признаки, которые могут быть в обучающей. Также в тестовом наборе нет целевых признаков.
#
# Исходный датасет содержит обучающую и тестовую выборки со всеми признаками.
#
# В нашем распоряжении сырые данные, выгруженные из хранилища. Прежде чем приступить к построению модели, проверим их на корректность
#
#
#
#
# **Технологический процесс:**
# * Rougher feed — исходное сырье
# * Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
#     * Xanthate — ксантогенат (промотер, или активатор флотации);
#     * Sulphate — сульфат (на данном производстве сульфид натрия);
#     * Depressant — депрессант (силикат натрия).
# * Rougher process (англ. «грубый процесс») — флотация
# * Rougher tails — отвальные хвосты
# * Float banks — флотационная установка
# * Cleaner process — очистка
# * Rougher Au — черновой концентрат золота
# * Final Au — финальный концентрат золота
#
# **Параметры этапов:**
# * air amount — объём воздуха
# * fluid levels — уровень жидкости
# * feed size — размер гранул сырья
# * feed rate — скорость подачи
#
# **Наименование признаков**
# Наименование признаков должно быть такое:
# `[этап].[тип_параметра].[название_параметра]`
# Пример: `rougher.input.feed_ag`
#
# Возможные значения для блока **[этап]**:
# * rougher — флотация
# * primary_cleaner — первичная очистка
# * secondary_cleaner — вторичная очистка
# * final — финальные характеристики
#
# Возможные значения для блока **[тип_параметра]**:
# * input — параметры сырья
# * output — параметры продукта
# * state — параметры, характеризующие текущее состояние этапа
# * calculation — расчётные характеристики

# %% [markdown]
# ### Расчет эффективности
# Нам смоделировать процесс восстановления золота из золотосодержащей руды.
# **Эффективность обогащения рассчитывается по формуле**
#
# $$
# Recovery = \frac{C*(F-T)}{F*(C-T)}*100\%
# $$
#
#
# где:
# * C — доля золота в концентрате после флотации/очистки;
# * F — доля золота в сырье/концентрате до флотации/очистки;
# * T — доля золота в отвальных хвостах после флотации/очистки.
#
# Для прогноза коэффициента нужно найти долю золота в концентратах и хвостах. Причём важен не только финальный продукт, но и черновой концентрат.

# %% [markdown]
# ### Используемая метрика качества
#
# Для решения задачи введём новую метрику качества — sMAPE (англ. Symmetric Mean Absolute Percentage Error, «симметричное среднее абсолютное процентное отклонение»).
#
# Она похожа на MAE, но выражается не в абсолютных величинах, а в относительных. Почему симметричная? Она одинаково учитывает масштаб и целевого признака, и предсказания.
#
# Метрика sMAPE вычисляется так:
#
# $$
# SMAPE = \frac{1}{N}\Sigma_{i=1}^N\frac{|y_i - \hat{y_i}|} {(|y_i| + |\hat{y_i}|)/2} * 100\%
# $$
#
#
# **Нужно спрогнозировать сразу две величины:**
# 1. эффективность обогащения чернового концентрата `rougher.output.recovery`;
# 2. эффективность обогащения финального концентрата `final.output.recovery`.
#
# Итоговая метрика складывается из двух величин:
#
# $$
# Итоговое\_SMAPE = 25\% * SMAPE(rougher) + 75\% * SMAPE(final)
# $$

# %% [markdown]
# ## Импорт библиотек

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier # решающее дерево для регрессии
from sklearn.ensemble import RandomForestRegressor # случайны лес для регрессии
from sklearn.linear_model import LinearRegression # линейная регрессия

# метрики качества
from sklearn.metrics import classification_report, SCORERS, r2_score, mean_absolute_error, mean_squared_error,\
mean_absolute_percentage_error, make_scorer, confusion_matrix
 
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, cross_val_score

from sklearn.preprocessing import StandardScaler # стандартизация данных
from sklearn.dummy import DummyRegressor

# import pandas_profiling

import warnings
warnings.filterwarnings("ignore")

# %config InlineBackend.figure_format = 'svg'
sns.set(style='whitegrid', color_codes=True, font_scale = 1.1)
from pylab import rcParams
rcParams['figure.figsize'] = 8, 5

pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

# %% [markdown]
# ## Загрузка и подготовка данных

# %% [markdown]
# ### Импорт данных

# %%
try:
    df_full = pd.read_csv('datasets/gold_recovery_full_new.csv') 
    df_train = pd.read_csv('datasets/gold_recovery_train_new.csv')
    df_test = pd.read_csv('datasets/gold_recovery_test_new.csv')
except:
    df_full = pd.read_csv('/datasets/gold_recovery_full_new.csv') #путь для ревьювера
    df_train = pd.read_csv('/datasets/gold_recovery_train_new.csv')
    df_test = pd.read_csv('/datasets/gold_recovery_test_new.csv')

# %%
for data in [df_full, df_train, df_test]:
    display(data.head(10))
    display(data.describe())
    data.info()
    print('_'*80, '\n')
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
# 5  2016-01-15 05:00:00                     6.482968
# 6  2016-01-15 06:00:00                     6.533849
# 7  2016-01-15 07:00:00                     6.130823
# 8  2016-01-15 08:00:00                     5.834140
# 9  2016-01-15 09:00:00                     5.687063
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
# ...

# %% [markdown]
# ### Проверим, что эффективность обогащения рассчитана правильно
# Вычислим её на обучающей выборке для признака rougher.output.recovery.
# Найдем MAE между вашими расчётами и значением признака.

# %%
c = df_train['rougher.output.concentrate_au']
t = df_train['rougher.output.tail_au']
f = df_train['rougher.input.feed_au'] 
rougher_recovery_calc = (c * (f - t)) * 100 / (f * (c - t))
print(rougher_recovery_calc)
print('\nMAE:', mean_absolute_error(df_train['rougher.output.recovery'], rougher_recovery_calc))
# Out:
# 0        87.107763
# 1        86.843261
# 2        86.842308
# 3        87.226430
# 4        86.688794
#            ...
# 14144    89.574376
# 14145    87.724007
# 14146    88.890579
# 14147    89.858126
# 14148    89.514960
# Length: 14149, dtype: float64
#
# MAE: 1.1131451184435918e-14

# %% [markdown]
# **Вывод:**
# Очень мальнькая средняя абсолютная ошибка между эффективностью из исходных данных и рассчетной эффективностью позволяет сделать вывод, что значениям эффективности исходных данных можно верить.

# %% [markdown]
# ### Предобработка данных
# Проанализируем признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?
# Проведем предобработку данных.

# %%
# приведем дату во всех df к стандартному отображению времени
for data in [df_full, df_train, df_test]:
    data['date'] = pd.to_datetime(data['date'], format='%Y-%m-%d %H:%M:%S')
type(df_train['date'][2])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# посмотрим за какой период данные в обучающей выборке
plt.figure(figsize = (11, 5))
sns.histplot(df_train['date'], binwidth=30)
# Out:
# <AxesSubplot:xlabel='date', ylabel='Count'>

# %% [markdown]
# Судя из описания проекта и исходных данных, признаки, отсутствующие в тестовой выборке - это "онлайн" данные, доступные только после прошедшего технологического процесса. Соответственно на этапе предсказания эти признаки отсутствуют, и модель о них ничего не знает. Значит и обучать ее на них не нужно, удалим их из обучающей выборки
#
# Но также, среди этих признаков находятся и целевые, их мы пока оставим.
#
# Также не придется обрабатывать лишние признаки с пропусками

# %%
# добавим целевые признаки в df_test из df_full используя дату
# можно использовать метод merge, выбрав правильное пересечение и общий пиризнак.
df_test['rougher.output.recovery'] = df_full[df_full['date'].isin(df_test['date'])]['rougher.output.recovery'].reset_index(drop=True)
df_test['final.output.recovery'] = df_full[df_full['date'].isin(df_test['date'])]['final.output.recovery'].reset_index(drop=True)
print(df_test.shape)
df_test.head()
# Out:
# (5290, 55)
#                  date  primary_cleaner.input.sulfate  \
# 0 2016-09-01 00:59:59                     210.800909
# 1 2016-09-01 01:59:59                     215.392455
# 2 2016-09-01 02:59:59                     215.259946
# 3 2016-09-01 03:59:59                     215.336236
# 4 2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# ...

# %%
columns_to_drop = set(df_train.columns) - set(df_test.columns) 
# - set(['rougher.output.recovery', 'final.output.recovery'])
columns_to_drop
# Out:
# {'final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.tail_ag',
#  'rougher.output.tail_au',
# ...

# %%
# так как предобработка данных, дело деликатное и всегда хочется сравнить с исходными данными, 
# с этого момента все операции c обучающей выборкой будем производить с датафремом под новой переменной  
df_train_processed = df_train.drop(columns_to_drop, axis = 1).copy()
df_train_processed.shape
# Out:
# (14149, 55)

# %%
# %%time
# # взглянем на отчет pandas_profiling
# profile = df_train.profile_report(minimal=False)
# profile.to_file("report2.html")

# %%
# проанализируем пропуски в тренировочной выборке
df_train_processed.isna().sum()[df_train_processed.isna().sum() > 0].sort_values(axis=0, ascending=False)
# Out:
# rougher.state.floatbank10_e_air               436
# rougher.input.floatbank11_xanthate            428
# secondary_cleaner.state.floatbank2_a_air      217
# rougher.input.feed_size                       144
# rougher.input.feed_pb                         100
# primary_cleaner.input.xanthate                100
# rougher.input.feed_sol                         78
# rougher.input.floatbank11_sulfate              36
# primary_cleaner.input.depressant               32
# rougher.input.floatbank10_sulfate              29
# secondary_cleaner.state.floatbank2_b_air       21
# primary_cleaner.input.sulfate                  20
# rougher.input.feed_rate                         8
# rougher.input.floatbank10_xanthate              8
# secondary_cleaner.state.floatbank4_a_air        6
# primary_cleaner.state.floatbank8_a_air          4
# primary_cleaner.state.floatbank8_b_air          4
# secondary_cleaner.state.floatbank3_a_air        4
# primary_cleaner.state.floatbank8_d_air          3
# ...

# %%
# подробнее посмотрим на признак с наибольшим кол-вом пропусков
display(df_train_processed[df_train_processed['rougher.state.floatbank10_e_air'].isna()].head(10))
plt.plot(df_train_processed[df_train_processed['rougher.state.floatbank10_e_air'].isna()].index)

# можно заметить, что пропуски характерных подряд для нескольких больших интервалов времени - прямые линии на графике
# Out:
#                     date  final.output.recovery  \
# 9843 2018-01-13 06:59:59              57.557984
# 9844 2018-01-13 07:59:59              63.659320
# 9845 2018-01-13 08:59:59              68.976483
# 9846 2018-01-13 09:59:59              65.439097
# 9847 2018-01-13 10:59:59              64.708091
# 9848 2018-01-13 11:59:59              66.782303
# 9849 2018-01-13 12:59:59              65.858005
# 9850 2018-01-13 13:59:59              62.441761
# 9851 2018-01-13 14:59:59              59.898617
# 9852 2018-01-13 15:59:59              62.133795
#
#       primary_cleaner.input.sulfate  primary_cleaner.input.depressant  \
# 9843                     171.875602                         10.509944
# 9844                     168.171593                         10.462669
# 9845                     168.963320                         10.806682
# 9846                     179.127784                         11.008129
# 9847                     185.013156                         10.986960
# ...

# %%
# предлагаю заменить пропуски на ближайшее последнее значение для признаков с количеством пропусков >= 100

# columns_to_fill = df_train_processed.isna().sum()[df_train_processed.isna().sum() >= 100].index
# for column in columns_to_fill:
#     df_train_processed[column] = df_train_processed[column].fillna(method='backfill')

# %%
# остальные пропуски удалим
df_train_processed = df_train_processed.dropna()
print(df_train_processed.shape)
print(f'Процент удаленных строк обучающей выборки: {((1 - df_train_processed.shape[0]/df_train.shape[0]) * 100):.2f}')
# Out:
# (12679, 55)
# Процент удаленных строк обучающей выборки: 10.39

# %% [markdown]
# В условиях есть указание, что соседние данные похожи. Можно протестировать работу моделей с заполнением по этому условию.
# Есть методы .ffill и .bfill, .interpolate , различные импутеры (на основе KNN или LinearRegresson), но главная наша цель конечно - лучшая метрика на тесте.
#
# Но в моем случае, если заполнять признаки с большим кол-вом пропусков методом backfill или ffil качество моделей оказалось хуже, чем если просто удалить все пропуски из обучающей выборки, пусть это и порядка 10% (пробовал и так и так).
#
# Поэтому пока остановился на варианте с удалением всех пропусков, но блоки под их обработку оставил и закоментил. Буду благодарен, если подскажешь подходящие в данном подход для обработки пропусков.

# %%
# посмотрим на пропуски в тестовой выборке
df_test.isna().sum()[df_test.isna().sum() > 0].sort_values(axis=0, ascending=False)
# Out:
# rougher.input.floatbank11_xanthate          25
# rougher.input.feed_sol                      21
# secondary_cleaner.state.floatbank3_a_air     9
# rougher.input.floatbank11_sulfate            8
# primary_cleaner.input.depressant             5
# rougher.input.floatbank10_sulfate            5
# primary_cleaner.input.sulfate                4
# primary_cleaner.input.xanthate               4
# rougher.input.feed_rate                      3
# secondary_cleaner.state.floatbank2_a_air     3
# secondary_cleaner.state.floatbank2_b_air     2
# rougher.input.feed_size                      1
# dtype: int64

# %%
# кол-во пропусков незначительно, поэтому просто удалим их
# к тому же эта выборка нужна только для проверки
df_test = df_test.dropna()
print(df_test.shape)
# Out:
# (5229, 55)

# %% [markdown]
# Также в датафрейме много нулей. С ними что-то можно сделать.
# Но например, если это концентрация металла, то это просто может означать пустую руду.
#
# 100% выбросами мы можем считать только нулевую суммарную концентрацию всех веществ. Эту очистку надо сделать в п.4.3

# %% [markdown]
# ## Анализ данных
# 1. Посмотрим, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки.
# 2. Сравним распределения размеров гранул сырья на обучающей и тестовой выборках.
# Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.
# 3. Исследуем суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.

# %% [markdown]
# ### Анализ концентрации металлов (Au, Ag, Pb) на различных этапах очистки

# %%
columns_to_plot = ['rougher.input.feed_ag', 'rougher.input.feed_pb', 'rougher.input.feed_au']
colors = ['skyblue', 'coral', 'orange']
legend = ['Ag', 'Pb', 'AU']
fig, ax = plt.subplots(figsize=(10, 5))

plt.title('Исходное сырье Au, Ag, Pb', fontsize=16)
for i in range(len(columns_to_plot)):
    sns.histplot(df_full[columns_to_plot[i]], color=colors[i])
    plt.legend(legend, loc=1)

# %%
columns_to_plot = ['rougher.output.concentrate_ag', 'rougher.output.concentrate_pb', 'rougher.output.concentrate_au']
fig, ax = plt.subplots( figsize=(10, 5))

plt.title('Концентрация металлов Au, Ag, Pb на этапе флотации', fontsize=16)
for i in range(len(columns_to_plot)):
    sns.histplot(df_full[columns_to_plot[i]], color=colors[i])
    plt.legend(legend, loc=1)

# %%
columns_to_plot = ['primary_cleaner.output.concentrate_ag', 'primary_cleaner.output.concentrate_pb', 'primary_cleaner.output.concentrate_au']
fig, ax = plt.subplots(figsize=(10, 5))

plt.title('Концентрация металлов Au, Ag, Pb на первом этапе очистки', fontsize=16)
for i in range(len(columns_to_plot)):
    sns.histplot(df_full[columns_to_plot[i]], color=colors[i])
    plt.legend(legend, loc=1)

# %%
columns_to_plot = ['final.output.concentrate_ag', 'final.output.concentrate_pb', 'final.output.concentrate_au']
fig, ax = plt.subplots(figsize=(10, 5))

plt.title('Концентрация металлов Au, Ag, Pb в финальном продукте', fontsize=16)
for i in range(len(columns_to_plot)):
    sns.histplot(df_full[columns_to_plot[i]], color=colors[i])
    plt.legend(legend, loc=1)

# %% [markdown]
# **Выводы:**
# * Концентрация серебра на выходе после флотации и очистки постепенно уменьшается, концентрация золота - увеличивается, концентрация свинца остается примерно на одном уровне;
# * Нет данных по концентрации металлов после второго этапа очистки? Есть только концентрация в хвостах.
# * Думаю нулевая концентрация золота на выходе - это нормально. Удалять нули не буду, модель тоже должна научиться с ними работать
#
# Также можно построить графики не по этапам, а по металлам, чтобы было видно динамику процесса

# %% [markdown]
# ### Анализ размера гранул сырья
# Сравним распределения размеров гранул сырья на обучающей и тестовой выборках.
# Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.

# %%
columns_to_plot = ['rougher.input.feed_size', 'primary_cleaner.input.feed_size']
# colors = ['skyblue', 'coral']
legend = ['rougher', 'primary_cleaner']
fig, ax = plt.subplots(2, 1, figsize=(10, 10), sharex=True)
plt.xlim(0, 150)


# plt.title('Концентрация металлов Au, Ag, Pb на этапе флотации', fontsize=16)
for i in range(len(columns_to_plot)):
    sns.histplot(df_train_processed[columns_to_plot[i]], color=colors[i], ax=ax[0]).set_title('Размер гранул. Обучающая выборка', fontsize=16)
    plt.legend(legend, loc=1)
    
for i in range(len(columns_to_plot)):
    sns.histplot(df_test[columns_to_plot[i]], color=colors[i], ax=ax[1]).set_title('Тестовая выборка', fontsize=16)
    plt.legend(legend, loc=1)

# %% [markdown]
# **Вывод:**
# Характер распределения размеров гранул сырья на обучающей и тестовой выборках в целом совпадает

# %%
plt.xlim(0, 150)
plt.title('Размер грану на входе для обучающей и тестовой выбоки')
sns.histplot(df_train['rougher.input.feed_size'], color='skyblue')
sns.histplot(df_test['rougher.input.feed_size'], color='orange')
plt.legend(['обучающая', 'тестовая'])

# %% [markdown]
# ### Анализ суммарной концентрации всех веществ на разных стадиях
# Исследуем суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.
#
# Построим распределение по df_train, так как неообходимые признаки из df_train_processd уже были удалены.

# %%
rougher_input_feed = df_train['rougher.input.feed_ag'] + df_train['rougher.input.feed_au'] + df_train['rougher.input.feed_pb'] +\
df_train['rougher.input.feed_sol']

rougher_output_concentrate = df_train['rougher.output.concentrate_ag'] + df_train['rougher.output.concentrate_pb'] +\
df_train['rougher.output.concentrate_au'] + df_train['rougher.output.concentrate_sol']  

final_output_concentrate = df_train['final.output.concentrate_ag'] + df_train['final.output.concentrate_pb'] +\
df_train['final.output.concentrate_au']  + df_train['final.output.concentrate_sol']

# %%
fig, ax = plt.subplots(3, 1,  figsize=(8, 14))
data_to_plot = [rougher_input_feed, rougher_output_concentrate, final_output_concentrate]
legend = (['rougher'], ['primary_cleaner'], ['final_output_concentrate'])
ax[0].set_title('Суммарная концентрация на разных этапах', fontsize=16)

for i, l in enumerate(legend): 
    sns.histplot(data_to_plot[i], color=colors[i], ax=ax[i], label='dff', legend=True)
    ax[i].legend(labels= l )

# %%
print(rougher_input_feed[rougher_input_feed == 0].count())
print(rougher_output_concentrate[rougher_output_concentrate == 0].count())
print(final_output_concentrate[final_output_concentrate == 0].count())
# Out:
# 0
# 297
# 58

# %% [markdown]
# Удалим строки из df_train_processed где суммарная концентрация всех веществ по этапу = 0 или около нулевая (по df_train).
# За порог примем значение 10.
#
# Для df_train_processed воспользуемся методом dtop c параметром errors = 'ignore', так как при удалении пропусков в df_train некоторые строки с нулями уже были удалены

# %%
index_to_drop = (
    rougher_output_concentrate[rougher_output_concentrate < 10].index
    .append(final_output_concentrate[final_output_concentrate < 10].index)
    .append(rougher_input_feed[rougher_input_feed < 10].index)
)

df_train_processed = df_train_processed.drop(labels=index_to_drop, axis=0, errors='ignore')
df_train_processed.shape
# Out:
# (12424, 55)

# %% [markdown]
# **Выводы:**
# * отсутствуют данные по концентрации металлов после второго этапа очистки
# * почему то после первого этапа очистки суммарная концентрация меньше, чем после флотации и финального этапа
# * если в суммарной концентрации не учитывать концентрацию sol (что это, в описании отсутствует), то концентрация остальных металлов будет расти
# * **в черновом и финальном концентрате для суммарной концентрации наблюдаются около нулевые значения. Строки с такими значениями были удалены как аномальные.**

# %% [markdown]
# ## Построение модели
# 1. Напишем функцию для вычисления итоговой sMAPE.
# 2. Обучим разные модели и оцените их качество кросс-валидацией.
# 3. Выбем лучшую модель и проверим её на тестовой выборке.

# %% [markdown]
# ### Разделение на выборки и масштабирование данных
# * Выделим фичи и целевой признак из обучающей и тестовой выборки. Валидационную выборку выделять не будем.
# * Обучим `StandartScaler()` на features_train
# * Масштабируем числовые признаки выборок features_train и features_test (по сути все признаки, кроме даты). Целевые признаки не масштабируем.
#
#
# Масштабирование полезно для линейных моделей. Качество "деревянных" или бустинговых моделей они не улучшают

# %%
features_train = df_train_processed.drop(['date', 'rougher.output.recovery', 'final.output.recovery'], axis=1)

target_train_rougher = df_train_processed['rougher.output.recovery']
target_train_final = df_train_processed['final.output.recovery']
print('Размер обучающей выборки фичей:', features_train.shape)
print('Размер обучающей выборки целевой флотация:', target_train_rougher.shape)
print('Размер обучающей выборки целевой финальный:', target_train_final.shape)
# Out:
# Размер обучающей выборки фичей: (12424, 52)
# Размер обучающей выборки целевой флотация: (12424,)
# Размер обучающей выборки целевой финальный: (12424,)

# %%
features_test = df_test.drop(['date', 'rougher.output.recovery', 'final.output.recovery'], axis=1)
# target_test = df_full[df_full['date'] == df_test['date']][['rougher.output.recovery', 'final.output.recovery']]
# логическая индексация не работает, потому что сравниваемые df разной длинны

target_test_rougher = df_test['rougher.output.recovery']
target_test_final = df_test['final.output.recovery']
print('Размер тестовой выборки фичей:', features_test.shape)
print('Размер тестовой выборки целевой флотация:', target_test_rougher.shape)
print('Размер тестовой выборки целевой финальный:', target_test_final.shape)
features_test.head(5)
# Out:
# Размер тестовой выборки фичей: (5229, 52)
# Размер тестовой выборки целевой флотация: (5229,)
# Размер тестовой выборки целевой финальный: (5229,)
#    primary_cleaner.input.sulfate  primary_cleaner.input.depressant  \
# 0                     210.800909                         14.993118
# 1                     215.392455                         14.987471
# 2                     215.259946                         12.884934
# 3                     215.336236                         12.006805
# 4                     199.099327                         10.682530
#
#    primary_cleaner.input.feed_size  primary_cleaner.input.xanthate  \
# 0                         8.080000                        1.005021
# 1                         8.080000                        0.990469
# 2                         7.786667                        0.996043
# 3                         7.640000                        0.863514
# 4                         7.530000                        0.805575
#
# ...

# %%
# на случай, если захочется обучить модель по двум целевым признакам
target_train = df_train_processed[['rougher.output.recovery', 'final.output.recovery']]
target_test = df_test[['rougher.output.recovery', 'final.output.recovery']]

# %% [markdown]
# Есть подозрение, что модели при обучении ругаются на тип datetime64[ns].
# Можно преобраовать в timestamp или григорианский порядковый номер (но тогда дата схлопнется до дней)
#
# Возможно вообще date нам при обучении и не нужен.
# *Upd. Да, такие уникальные идентификаторы (индексы, фио, даты конкретных событий и пр) при обучении моделей почти никогда не используют*

# %%
# обучим StandardScaler() на обучающей выборке
numeric = features_train.columns 
scaler = StandardScaler().fit(features_train[numeric])

# если задать без индексации features_train на прямую потеряется структура pandas
features_train[numeric] = scaler.transform(features_train[numeric])
features_test[numeric] = scaler.transform(features_test[numeric])
display(features_train.head(5))
features_test.head(5)
# Out:
#    primary_cleaner.input.sulfate  primary_cleaner.input.depressant  \
# 0                      -0.265729                          0.302746
# 1                      -0.305223                          0.353610
# 2                      -0.354076                          0.662517
# 3                      -0.395915                          0.664292
# 4                      -0.511526                          0.843414
#
#    primary_cleaner.input.feed_size  primary_cleaner.input.xanthate  \
# 0                        -0.152059                        0.277603
# 1                        -0.152059                        0.315874
# 2                        -0.152059                        0.284502
# 3                        -0.152059                        0.299567
# 4                        -0.152059                        0.335709
#
#    primary_cleaner.state.floatbank8_a_air  \
# 0                               -0.430863
# 1                               -0.226807
# ...

# %% [markdown]
# ### Функция для вычисления sMAPE
#
# Нжно использовать функцию make_scorer. С помощью нее создать скоринг, который считает smape. И потом использовать ее в параметре скоринг в кросс-валидации
#
# Продублирую формулы метрик:
#
# $$
# SMAPE = \frac{1}{N}\Sigma_{i=1}^N\frac{|y_i - \hat{y_i}|} {(|y_i| + |\hat{y_i}|)/2} * 100\%
# $$
#
# $$
# Итоговое\_SMAPE = 25\% * SMAPE(rougher) + 75\% * SMAPE(final)
# $$

# %%
# создадим функцию для вывода основных метрик качества моделей регрессии + sMAPE
# sMAPE поставим на вывод, чтобы можно было воспользоваться этой функцией при кроссвалидации
def model_metrics(target, predictions):
    smape = 100 / len(target) * np.sum(2 * abs(target - predictions) / (abs(target) + abs(predictions)))
    print(f'MSE:   {mean_squared_error(target, predictions):.2f}')
    print(f'RMSE:  {np.sqrt(mean_squared_error(target, predictions)):.2f}')
    print(f'R2:    {r2_score(target, predictions):.2f}')
    print(f'MAE:   {mean_absolute_error(target, predictions):.2f}')
    print(f'MAPE:  {mean_absolute_percentage_error(target, predictions):.2f} %')
    print(f'sMAPE: {smape:.2f} %')
    print('_'*20)
    return smape

# %%
def smape(target, predictions):
    smape = 100 / len(target) * np.sum(2 * abs(target - predictions) / (abs(target) + abs(predictions)))
    return smape

# %%
def smape_total(smape_rougher, smape_final):
    return 0.25*smape_rougher + 0.75*smape_final

# %% [markdown]
# ### Обучение моделей
#
# Рассмотрим модели линейной регрессии и случайного леса. Обозначим их индексами `rfr` и `lr`.
#
# Для каждого алгоритма создадим по две модели:
# * c индексом `rougher` - предсказывает эффективность обогащения чернового концентрата после флотации (`rougher.output.recovery`);
# * с индексом `final` - предсказывает эффективность обогащения финального концентрата (`final.output.recovery`).
#
# Для подбора гиперпараметров моделей случайного леса воспользуемся Randomized Search и Grid Search(но чувствую, что тут по загрузке все будет очень долго).
#
# Для оценки качества моделей воспользуемся кроссвалидвацией.

# %% [markdown]
# #### Оценка среднего целевого признака и Dummy модель
#
# Прежде всего оцценим средние значения целевых признаков обучающей выборки для понимания значений и оценки результатов моделей, а также построим бэйслайн модель с помощью DummyRegressor

# %%
print('Средняя эфф.обогащения после флотации:', df_train_processed['rougher.output.recovery'].mean())
print(f'Средняя эфф.обогащения финального концентрата:', df_train_processed['final.output.recovery'].mean())
# Out:
# Средняя эфф.обогащения после флотации: 84.4730922701927
# Средняя эфф.обогащения финального концентрата: 66.87722236208931

# %%
# создадим scorer для кроссвалидации по метрике sMAPE
scorer = make_scorer(smape, greater_is_better=True)
scorer_loss = make_scorer(smape, greater_is_better=False)

# %%
model_dummy_rougher = DummyRegressor().fit(features_train, target_train_rougher)
predictions_dummy = model_dummy_rougher.predict(features_test) 
model_metrics(target_test_rougher, predictions_dummy)
# Out:
# MSE:   167.64
# RMSE:  12.95
# R2:    -0.00
# MAE:   6.00
# MAPE:  6984426609218557.00 %
# sMAPE: 8.95 %
# ____________________
# 8.952439360763163

# %%
cross_val_score(model_dummy_rougher, features_train, target_train_rougher, cv=5, scoring=scorer).mean()
# Out:
# 7.549704500453636

# %%
model_dummy_final = DummyRegressor().fit(features_train, target_train_final)
predictions_dummy = model_dummy_final.predict(features_test) 
model_metrics(target_test_final, predictions_dummy)
# Out:
# MSE:   81.26
# RMSE:  9.01
# R2:    -0.04
# MAE:   6.04
# MAPE:  1612788400050758.75 %
# sMAPE: 9.53 %
# ____________________
# 9.529214927180941

# %%
cross_val_score(model_dummy_final, features_train, target_train_final, cv=5, scoring=scorer).mean()
# Out:
# 9.718710197036527

# %% [markdown]
# #### Rougher Linear Regression

# %%
# посмотрим на метрики модели по умолчанию на обучающей выбрке
model_lr_rougher = LinearRegression()
model_lr_rougher.fit(features_train, target_train_rougher)
# Out:
# LinearRegression()

# %%
# Воспользуемся кросс-валидацией
print(cross_val_score(model_lr_rougher, features_train, target_train_rougher, cv=5, scoring=scorer))
cross_val_score(model_lr_rougher, features_train, target_train_rougher, cv=5, scoring=scorer).mean()
# Out:
# [7.31766459 7.06079647 7.7893338  4.22544828 7.89731901]
# 6.85811243174404

# %%
# проверим на тестовой выборке
predictions_lr_rougher = model_lr_rougher.predict(features_test)
model_metrics(target_test_rougher, predictions_lr_rougher)
# Out:
# MSE:   160.25
# RMSE:  12.66
# R2:    0.04
# MAE:   5.61
# MAPE:  6925684989347995.00 %
# sMAPE: 8.56 %
# ____________________
# 8.562332704793635

# %%
# попробуем подобрать гиперпараметры
model_lr_rougher = LinearRegression(copy_X=True, fit_intercept=True, normalize=False)
model_lr_rougher.fit(features_train, target_train_rougher)
cross_val_score(model_lr_rougher, features_train, target_train_rougher, cv=5, scoring=scorer).mean()
# Out:
# 6.85811243174404

# %%
best_model_rougher = model_lr_rougher

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ⚠️\
# <font color='darkorange'> Тесты на тренировочных данных малоинформативны. Сейчас мы предварительно оцениваем модели, для оценки используется либо отдельная оценочная (валидационная) выборка либо кроссвалидация (перекрёстная оценка), где валидационная выборка генерится внутри автоматически. </font>

# %%
Для этих данных конечно хочеться выделить валидационную выборку, кроссвалидация для Random Forest у меня работает очень дого.

Но насколько я понимаю в задании предлагается использовать именно кроссвалидацию.

Далее все проверял с помощью кроссвалидации кроме модели RandomizedSearch - там сразу выводил метрики по лучшим параметрам (там кроссвалидация уже внутри зашита)

# %%
# посмотрим из-за чего получилось такое большое MAPE, возможно из-за деления на ноль
target_train_rougher[target_train_rougher == 0]
# Out:
# Series([], Name: rougher.output.recovery, dtype: float64)

# %% [markdown]
# Почему кросс-валидация выдает все отрицательные значения sMAPE?
#
# За отрицательное значение отвечает аргумент `greater_is_better=False` он важен для алгоритмов серии SearchCV, поскольку те ищут наибольшее значение метрики по умолчанию. Для cross_val_score он не нужен
#
# greater_is_better - переводится как больше-лучше, это не наш случай.  RandomizedSearchCV отбирает наибольшую метрику, подавая ему отрицательные значения мы принуждаем его искать наибольшее отрицательное значение - то есть ближе к нулю. Метрика в этом случае оценивается по модулю.

# %% [markdown]
# #### Final. Linear Regression

# %%
# модель с параметрами по умолчанию для финального обогащения 
model_lr_final = LinearRegression(copy_X=True, fit_intercept=True, normalize=False)
model_lr_final.fit(features_train, target_train_final)
cross_val_score(model_lr_final, features_train, target_train_final, cv=5, scoring=scorer).mean()
# Out:
# 10.168505759328047

# %%
predictions_lr_final = model_lr_final.predict(features_test)
model_metrics(target_test_final, predictions_lr_final)
# Out:
# MSE:   78.04
# RMSE:  8.83
# R2:    0.00
# MAE:   5.72
# MAPE:  1573832829312511.75 %
# sMAPE: 9.05 %
# ____________________
# 9.05403480965389

# %% [markdown]
# #### Rougher. Случайный лес

# %%
# %%time
RANDOM_STATE=12345

model_rfr_rougher = RandomForestRegressor(random_state=RANDOM_STATE)
model_rfr_rougher.fit(features_train, target_train_rougher)
# Out:
# Wall time: 56.9 s
# RandomForestRegressor(random_state=12345)

# %%
# %%time
cross_val_score(model_rfr_rougher, features_train, target_train_rougher, cv=3, scoring=scorer).mean()
# Out:
# Wall time: 1min 49s
# 7.774542626059675

# %%
# проверим на тестовой выборке
predictions_rfr_rougher = model_rfr_rougher.predict(features_test) 
model_metrics(target_test_rougher, predictions_rfr_rougher)
# Out:
# MSE:   155.19
# RMSE:  12.46
# R2:    0.07
# MAE:   5.02
# MAPE:  6940420608280256.00 %
# sMAPE: 7.85 %
# ____________________
# 7.852624657314539

# %%
# подберем гиперпараметры с помощью RandomizedSearch
# зададим гиперпараметры и их диапазон для перебора с помощью словаря
parameters_rs = {'criterion': ['squared_error', 'absolute_error', 'poisson'],
                 'n_estimators': list(range(10, 151, 10)),
                 'max_depth': list(range(2,22,2)),
                 'max_leaf_nodes': list(range(50,351,50)),
                 'min_samples_split': list(range(3, 22, 2)),
                 'min_samples_leaf': list(range(1, 22, 2)),
                 'max_features': ['auto', 'sqrt', 'log2']}

# %%
parameters_rs_2 = {'n_estimators': list(range(5, 200, 5)),
                 'max_depth': list(range(2,40,2)),
                 'min_samples_split': list(range(3, 22, 2)),
                 'min_samples_leaf': list(range(1, 22, 2))}

# %%
# %%time
# подбирать параметры стоит на основе целевой метрики, то есть smape 
# для этого из нее нужно сделать scorer с помощью функции make_scorer
scorer_loss = make_scorer(smape, greater_is_better=False)

model_rfr_rougher = RandomForestRegressor(random_state=RANDOM_STATE)
rs_rougher = RandomizedSearchCV(
    model_rfr_rougher, parameters_rs_2, n_jobs=4, verbose=2, scoring=scorer_loss, random_state=RANDOM_STATE, n_iter=30,  cv=3)
rs_rougher.fit(features_train, target_train_rougher)
print(rs_rougher.best_params_)
# Out:
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# {'n_estimators': 10, 'min_samples_split': 3, 'min_samples_leaf': 19, 'max_depth': 2}
# Wall time: 13min 18s

# %%
# %%time
score_rfr_rougher = cross_val_score(rs_rougher.best_estimator_, features_train, target_train_rougher, cv=3, scoring=scorer).mean()
score_rfr_rougher
# Out:
# Wall time: 1.8 s
# 7.502807641386405

# %%
# выведем лучшие гиперпараметры по результатам Randomized Search и метрики модели на тестовой выборке с этими гиперпараметрами

model_metrics(target_test_rougher, rs_rougher.predict(features_test))
# Out:
# MSE:   161.28
# RMSE:  12.70
# R2:    0.04
# MAE:   5.45
# MAPE:  6998797786613055.00 %
# sMAPE: 8.34 %
# ____________________
# 8.340498619352253

# %%
# %%time
# # для экпериментов и ручного подбора параметров

# model_rfr_rougher = RandomForestRegressor(
#     random_state=RANDOM_STATE, n_estimators=160, criterion='squared_error', max_depth=5, max_features='sqrt',
#     min_samples_split=8, min_samples_leaf=1, max_leaf_nodes=None, n_jobs=-1
# )
# model_rfr_rougher.fit(features_train, target_train_rougher)

# %%
# cross_val_score(model_rfr_rougher, features_train, target_train_final, cv=3, scoring=scorer).mean()

# %%
# model_metrics(target_test_rougher, model_rfr_rougher.predict(features_test))

# %% [markdown]
# #### Final Случайный лес

# %%
# %%time
# модель с параметрами по умолчанию 

model_rfr_final = RandomForestRegressor(random_state=RANDOM_STATE)
model_rfr_final.fit(features_train, target_train_final)

# %%
# %%time
cross_val_score(model_rfr_final, features_train, target_train_final, cv=3, scoring=scorer).mean()

# %%
predictions_rfr_final = model_rfr_final.predict(features_test) 
model_metrics(target_test_final, predictions_rfr_final)

# %%
# %%time
# подберем гиперпараметры с помощью RSCV

model_rfr_final = RandomForestRegressor(random_state=RANDOM_STATE)
rs_final = RandomizedSearchCV(
    model_rfr_final, parameters_rs_2, n_jobs=4, verbose=2, scoring=scorer_loss, random_state=RANDOM_STATE, n_iter=30,  cv=3)
rs_final.fit(features_train, target_train_final)
print(rs_final.best_params_)
rs_final.cv
# Out:
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# {'n_estimators': 105, 'min_samples_split': 17, 'min_samples_leaf': 3, 'max_depth': 24}
# Wall time: 18min 15s
# 3

# %%
# %%time
score_rfr_final_cv = cross_val_score(rs_final.best_estimator_, features_train, target_train_final, cv=3, scoring=scorer).mean()
score_rfr_final
# Out:
# Wall time: 1min 56s
# 9.104173885180623

# %%
score_rfr_final = model_metrics(target_test_final, rs_final.predict(features_test))
# Out:
# MSE:   77.66
# RMSE:  8.81
# R2:    0.01
# MAE:   5.68
# MAPE:  1510382687215874.00 %
# sMAPE: 9.10 %
# ____________________

# %%
# примем за лучшую модель для final
best_model_final = rs_final.best_estimator_

# %% [markdown]
# ### Выбор лучшей модели и проверка на тестовой выборке
# * Выберем лучшии модели по результатам кроссвалидации
# * Посчитаем итоговое sMAPE на тестовой выборке
#
# Для rougher "наилучшие" результаты показала модель с линейной регрессией, для final - случаный лес с подобранными RandomizedSearchCV гиперпараметрами

# %%
smape_result = smape_total(smape(target_test_rougher, best_model_rougher.predict(features_test)),\
            smape(target_test_final, best_model_final.predict(features_test)))
smape_baseline = smape_total(smape(target_test_rougher, model_dummy_rougher.predict(features_test)),\
            smape(target_test_final, model_dummy_final.predict(features_test)))


print(f'Итоговое sMAPE: {smape_result:.2f}')
print(f'Baseline sMAPE: {smape_baseline:.2f}')
# Out:
# Итоговое sMAPE: 8.97
# Baseline sMAPE: 9.39

# %% [markdown]
#
# Пока очень не доволен собственными результатами по пятому разделу. Несколько раз перепроверил обработку исходных данных и попробовал разные варианты
# Основные проблемные на текущий момент для меня вопросы:
#
# - правльно ли я поступил с пропусками и в целом провел обработку данных и разбивку на выборки;
# - на тестовой выборке получаются очень плохие метрики (вплоть до отрицательного коэффициента детерминации);
# - кросс валидация показывает очень странные для меня результаты (также отрицательные метрики). В случае sMAPE как будто, если взять модуль будет похоже на правду.
# - гиперпараметры пока не подобрал, потому что чувствую, что то делаю не так. Планирую использовать Randomized Search, потому что даже для кросс-валидации с пятью фолдами ноутбук уходит думать на 5-10 мин
#
# Стоиит вместо RandomizedSearchCV воспользоваться OptunaSearchCV. Гиперпараметры нужно подбирать по smape
# И попробовать добавить бустинг.
